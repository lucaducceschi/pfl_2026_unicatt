# %% [markdown]
# # 🐍 Programming for Linguistics (PfL) 2026
# ## Notebook 01-02: Foundations and Web Scraping
#
# Welcome to the first part of our course! In this notebook, we lay the groundwork for using Python as a tool for **Computational Linguistics**. We will transition from simple data structures to gathering live data from the internet.
#
# ---
#
# ### 🎯 Learning Objectives
# 1. **Environment Setup**: Learning how to install and import libraries.
# 2. **Data Structures**: Mastering **Lists** and **Dictionaries** for analyzing text.
# 3. **Web Scraping**: Using `requests` and `BeautifulSoup` to extract data from HTML.
# 4. **Systematic Processing**: Writing functions and loops to manage linguistic datasets.
#
# ---
#
# ### 🛠️ Step 1: Installing Dependencies
# In Python, we use the `%pip install` command to download external tools. Think of these as adding specialized plugins to your browser.

# %%
# %pip install git+git://github.com/lucaducceschi/plainstream.git

# %% [markdown]
# ### 📦 Libraries and Data Loading
# We rely on **libraries** (pre-written code) to interact with the web:
# - `requests`: This is your digital mailman. It sends requests to servers and brings back their response (HTML).
# - `plainstream`: A specialized tool for reading text data.
# - `BeautifulSoup`: This is a "parser" that understands the messy structure of a webpage.

# %%
import plainstream
import requests


url = 'https://raw.githubusercontent.com/mahlberg-lab/corpora/refs/heads/master/ChiLit/alice.txt'
url
# Out:
# 'https://raw.githubusercontent.com/mahlberg-lab/corpora/refs/heads/master/ChiLit/alice.txt'

# %%
r = requests.get(url)https://raw.githubusercontent.com/mahlberg-lab/corpora/refs/heads/master/ChiLit/alice.txt
r.text
# Out:
# 'Alice’s Adventures in Wonderland\nLewis Carroll\n\nCHAPTER I. Down the Rabbit-Hole\n\nAlice was beginning to get very tired of sitting by her sister on the\nbank, and of having nothing to do: once or twice she had peeped into the\nbook her sister was reading, but it had no pictures or conversations in\nit, ‘and what is the use of a book,’ thought Alice ‘without pictures or\nconversations?’\n\nSo she was considering in her own mind (as well as she could, for the\nhot day made her feel very sleepy and stupid), whether the pleasure\nof making a daisy-chain would be worth the trouble of getting up and\npicking the daisies, when suddenly a White Rabbit with pink eyes ran\nclose by her.\n\nThere was nothing so VERY remarkable in that; nor did Alice think it so\nVERY much out of the way to hear the Rabbit say to itself, ‘Oh dear!\nOh dear! I shall be late!’ (when she thought it over afterwards, it\noccurred to her that she ought to have wondered at this, but at the time\nit all seemed quite natural); but when the Rabbit actually TOOK A WATCH\nOUT OF ITS WAISTCOAT-POCKET, and looked at it, and then hurried on,\nAlice started to her feet, for it flashed across her mind that she had\nnever before seen a rabbit with either a waistcoat-pocket, or a watch\nto take out of it, and burning with curiosity, she ran across the field\nafter it, and fortunately was just in time to see it pop down a large\nrabbit-hole under the hedge.\n\nIn another moment down went Alice after it, never once considering how\nin the world she was to get out again.\n\nThe rabbit-hole went straight on like a tunnel for some way, and then\ndipped suddenly down, so suddenly that Alice had not a moment to think\nabout stopping herself before she found herself falling down a very deep\nwell.\n\nEither the well was very deep, or she fell very slowly, for she had\nplenty of time as she went down to look about her and to wonder what was\ngoing to happen next. First, she tried to look down and make out what\nshe was coming to, but it was too dark to see anything; then she\nlooked at the sides of the well, and noticed that they were filled with\ncupboards and book-shelves; here and there she saw maps and pictures\nhung upon pegs. She took down a jar from one of the shelves as\nshe passed; it was labelled ‘ORANGE MARMALADE’, but to her great\ndisappointment it was empty: she did not like to drop the jar for fear\nof killing somebody, so managed to put it into one of the cupboards as\nshe fell past it.\n\n‘Well!’ thought Alice to herself, ‘after such a fall as this, I shall\nthink nothing of tumbling down stairs! How brave they’ll all think me at\nhome! Why, I wouldn’t say anything about it, even if I fell off the top\nof the house!’ (Which was very likely true.)\n\nDown, down, down. Would the fall NEVER come to an end! ‘I wonder how\nmany miles I’ve fallen by this time?’ she said aloud. ‘I must be getting\nsomewhere near the centre of the earth. Let me see: that would be four\nthousand miles down, I think--’ (for, you see, Alice had learnt several\nthings of this sort in her lessons in the schoolroom, and though this\nwas not a VERY good opportunity for showing off her knowledge, as there\nwas no one to listen to her, still it was good practice to say it over)\n‘--yes, that’s about the right distance--but then I wonder what Latitude\nor Longitude I’ve got to?’ (Alice had no idea what Latitude was, or\nLongitude either, but thought they were nice grand words to say.)\n\nPresently she began again. ‘I wonder if I shall fall right THROUGH the\nearth! How funny it’ll seem to come out among the people that walk with\ntheir heads downward! The Antipathies, I think--’ (she was rather glad\nthere WAS no one listening, this time, as it didn’t sound at all the\nright word) ‘--but I shall have to ask them what the name of the country\nis, you know. Please, Ma’am, is this New Zealand or Australia?’ (and\nshe tried to curtsey as she spoke--fancy CURTSEYING as you’re falling\nthrough the air ...

# %%
# url_post = "https://www.ilpost.it/2026/02/26/limiti-problemi-amnistia-venezuela/?homepagePosition=0"
# r2 = requests.get(url_post)
# r2.text

# %%
s = r.text
# Out:
# 'Alice’s Adventures in Wonderland\nLewis Carroll\n\nCHAPTER I. Down the Rabbit-Hole\n\nAlice was beginning to get very tired of sitting by her sister on the\nbank, and of having nothing to do: once or twice she had peeped into the\nbook her sister was reading, but it had no pictures or conversations in\nit, ‘and what is the use of a book,’ thought Alice ‘without pictures or\nconversations?’\n\nSo she was considering in her own mind (as well as she could, for the\nhot day made her feel very sleepy and stupid), whether the pleasure\nof making a daisy-chain would be worth the trouble of getting up and\npicking the daisies, when suddenly a White Rabbit with pink eyes ran\nclose by her.\n\nThere was nothing so VERY remarkable in that; nor did Alice think it so\nVERY much out of the way to hear the Rabbit say to itself, ‘Oh dear!\nOh dear! I shall be late!’ (when she thought it over afterwards, it\noccurred to her that she ought to have wondered at this, but at the time\nit all seemed quite natural); but when the Rabbit actually TOOK A WATCH\nOUT OF ITS WAISTCOAT-POCKET, and looked at it, and then hurried on,\nAlice started to her feet, for it flashed across her mind that she had\nnever before seen a rabbit with either a waistcoat-pocket, or a watch\nto take out of it, and burning with curiosity, she ran across the field\nafter it, and fortunately was just in time to see it pop down a large\nrabbit-hole under the hedge.\n\nIn another moment down went Alice after it, never once considering how\nin the world she was to get out again.\n\nThe rabbit-hole went straight on like a tunnel for some way, and then\ndipped suddenly down, so suddenly that Alice had not a moment to think\nabout stopping herself before she found herself falling down a very deep\nwell.\n\nEither the well was very deep, or she fell very slowly, for she had\nplenty of time as she went down to look about her and to wonder what was\ngoing to happen next. First, she tried to look down and make out what\nshe was coming to, but it was too dark to see anything; then she\nlooked at the sides of the well, and noticed that they were filled with\ncupboards and book-shelves; here and there she saw maps and pictures\nhung upon pegs. She took down a jar from one of the shelves as\nshe passed; it was labelled ‘ORANGE MARMALADE’, but to her great\ndisappointment it was empty: she did not like to drop the jar for fear\nof killing somebody, so managed to put it into one of the cupboards as\nshe fell past it.\n\n‘Well!’ thought Alice to herself, ‘after such a fall as this, I shall\nthink nothing of tumbling down stairs! How brave they’ll all think me at\nhome! Why, I wouldn’t say anything about it, even if I fell off the top\nof the house!’ (Which was very likely true.)\n\nDown, down, down. Would the fall NEVER come to an end! ‘I wonder how\nmany miles I’ve fallen by this time?’ she said aloud. ‘I must be getting\nsomewhere near the centre of the earth. Let me see: that would be four\nthousand miles down, I think--’ (for, you see, Alice had learnt several\nthings of this sort in her lessons in the schoolroom, and though this\nwas not a VERY good opportunity for showing off her knowledge, as there\nwas no one to listen to her, still it was good practice to say it over)\n‘--yes, that’s about the right distance--but then I wonder what Latitude\nor Longitude I’ve got to?’ (Alice had no idea what Latitude was, or\nLongitude either, but thought they were nice grand words to say.)\n\nPresently she began again. ‘I wonder if I shall fall right THROUGH the\nearth! How funny it’ll seem to come out among the people that walk with\ntheir heads downward! The Antipathies, I think--’ (she was rather glad\nthere WAS no one listening, this time, as it didn’t sound at all the\nright word) ‘--but I shall have to ask them what the name of the country\nis, you know. Please, Ma’am, is this New Zealand or Australia?’ (and\nshe tried to curtsey as she spoke--fancy CURTSEYING as you’re falling\nthrough the air ...

# %%
tokens =  s.split()
type(r)
# Out:
# requests.models.Response

# %%
len(tokens)
# Out:
# 26444

# %%
import nltk
from nltk import word_tokenize

# %%
# nltk.download('punkt')
tokens = word_tokenize(s)

# %%
c =0 

for t in tokens:
    if t == "Alice":
        c+=1
c
# Out:
# 396

# %%
a = 8
# a = 
# a
# a = a +10
a +=10
a
# Out:
# 18

# %%
d = {}
for t in tokens:
    if t in d:
         +=1
    else:
        d[t] = 1
d
# Out:
# {'Alice': 396,
#  '’': 1759,
#  's': 195,
#  'Adventures': 3,
#  'in': 354,
#  'Wonderland': 3,
#  'Lewis': 1,
#  'Carroll': 1,
#  'CHAPTER': 12,
#  'I': 543,
#  '.': 785,
#  'Down': 3,
#  'the': 1522,
#  'Rabbit-Hole': 1,
#  'was': 351,
#  'beginning': 14,
#  'to': 720,
#  'get': 44,
#  'very': 126,
#  'tired': 7,
#  'of': 497,
#  'sitting': 10,
#  'by': 54,
#  'her': 243,
#  'sister': 9,
#  'on': 187,
#  'bank': 3,
#  ',': 2418,
#  'and': 796,
#  'having': 10,
#  'nothing': 29,
#  'do': 65,
#  ':': 233,
#  'once': 29,
#  'or': 76,
#  'twice': 5,
#  'she': 509,
#  'had': 177,
#  'peeped': 3,
#  'into': 67,
#  'book': 7,
#  'reading': 3,
#  'but': 133,
#  'it': 518,
#  'no': 69,
#  'pictures': 4,
#  'conversations': 2,
#  '‘': 1112,
#  'what': 93,
#  'is': 94,
#  'use': 18,
#  'a': 614,
#  'thought': 74,
#  'without': 26,
#  '?': 202,
#  'So': 27,
#  'considering': 3,
#  'own': 10,
#  'mind': 8,
#  '(': 54,
#  'as': 246,
#  'well': 37,
#  'could': 73,
#  'for': 139,
#  'hot': 5,
#  'day': 24,
#  'made': 30,
#  'feel': 8,
#  'sleepy': 5,
#  'stupid': 5,
#  ')': 56,
#  'whether': 11,
#  'pleasure': 2,
#  'making': 8,
#  'daisy-chain': 1,
#  'would': 70,
#  'be': 144,
#  'worth': 4,
#  'trouble': 6,
#  'getting': 22,
#  'up': 94,
#  'picking': 2,
#  'daisies': 1,
#  'when': 69,
#  'suddenly': 12,
#  'White': 22,
#  'Rabbit': 44,
#  'with': 175,
#  'pink': 1,
#  'eyes': 28,
#  'ran': 16,
#  'close': 13,
#  'There': 33,
#  'so': 123,
#  'VERY': 13,
#  'remarkable': 2,
#  'that': 272,
#  ';': 194,
#  'nor': 2,
#  'did': 60,
#  'think': 49,
#  'much': 51,
#  'out': 111,
#  'way': 53,
#  'hear': 14,
#  'say': 49,
#  'itself': 14,
#  'Oh': 35,
#  'dear': 28,
#  '!': 450,
#  'shall': 23,
#  'late': 5,
#  'over': 40,
#  'afterwards': 1,
#  'occurred': 2,
#  'ought': 14,
#  'have': 73,
#  'wondered': 1,
#  'at': 202,
#  'this': 113,
#  'time': 64,
#  'all': 171,
#  'seemed': 27,
#  'quite': 53,
#  'natural': 4,
#  'actually': 1,
#  'TOOK': 1,
#  'A': 17,
#  'WATCH': 1,
#  'OUT': 1,
#  'OF': 3,
#  'ITS': 1,
#  'WAISTCOAT-POCKET': 1,
#  'looked': 45,
#  'then': 70,
#  'hurried': 11,
#  'started': 2,
#  'feet': 19,
#  'flashed': 1,
#  'across': 5,
#  'never': 41,
#  'before': 35,
#  'seen': 15,
#  'rabbit': 2,
#  'either': 9,
#  'waistcoat-pocket': 1,
#  'watch': 7,
#  'take': 18,
#  'burning': 1,
#  'curiosity': 5,
#  'field': 1,
#  'after': 36,
#  'fortunately': 1,
#  'just': 45,
#  'see': 65,
#  'pop': 1,
#  'down': 99,
#  'large': 33,
#  'rabbit-hole': 3,
#  'under': 16,
#  'hedge': 2,
#  'In': 11,
#  'another': 22,
#  'moment': 31,
#  'went': 83,
#  'how': 40,
#  'world': 7,
#  'again': 81,
#  'The': 108,
#  'straight': 2,
#  'like': 83,
#  'tunnel': 1,
#  'some': 48,
#  'dipped': 2,
#  'not': 128,
#  'about': 94,
#  'stopping': 1,
#  'herself': 83,
#  'found': 30,
#  'falling': 2,
#  'deep': 7,
#  'Either': 1,
#  'fell': 6,
#  'slowly': 8,
#  'plenty': 1,
#  'look': 27,
#  'wonder': 18,
#  'going': 27,
#  'happen': 8,
#  'next': 28,
#  'First': 7,
#  'tried': 19,
#  'make': 27,
#  'coming': 8,
#  'too': 24,
#  'dark': 3,
#  'anything': 19,
#  'sides': 4,
#  'noticed': 8,
#  'they': 129,
#  'were': 85,
#  'filled': 3,
#  'cupboards': 2,
#  'book-shelves': 1,
#  'here': 37,
#  'there': 65,
#  'saw': 14,
#  'maps': 1,
#  'hung': 1,
#  'upon': 26,
#  'pegs': 1,
#  'She': 39,
#  'took': 23,
#  'jar': 2,
#  'from': 34,
#  'one': 94,
#  'shelves': 1,
#  'passed': 5,
#  'labelled': 1,
#  'ORANGE': 1,
#  'MARMALADE': 1,
#  'great': 39,
#  'disappointment': 1,
#  'empty': 1,
#  'drop': 1,
#  'fear': 4,
#  'killing': 1,
#  'somebody': 4,
#  'managed': 4,
#  'put': 31,
#  'past': 1,
#  'Well': 23,
#  'such': 40,
#  'fall': 7,
#  'tumbling': 2,
#  'stairs': 3,
#  'How': 27,
#  'brave': 1,
#  'll': 56,
#  'me': 60,
#  'home': 5,
#  'Why': 27,
#  'wouldn': 12,
#  't': 216,
#  'even': 17,
#  'if': 78,
#  'off': 61,
#  'top': 8,
#  'house': 18,
#  'Which': 8,
#  'likely': 5,
#  'true': 3,
#  'Would': 8,
#  'NEVER': 2,
#  'come': 25,
#  'an': 52,
#  'end': 16,
#  'many': 12,
#  'miles': 3,
#  've': 43,
#  'fallen': 4,
#  'said': 456,
#  'aloud': 5,
#  'must': 41,
#  'somewhere': 1,
#  'near': 14,
#  'centre': 1,
#  'earth': 4,
#  'Let': 11,
#  'four': 6,
#  'thousand': 2,
#  '--': 264,
#  'you': 344,
#  'learnt': 2,
#  'several': 4,
#  'things': 30,
#  'sort': 20,
#  'lessons': 10,
#  'schoolroom': 1,
#  'though': 10,
#  'good': 24,
#  'opportunity': 8,
#  'showing': 2,
#  'knowledge': 3,
#  'listen': 7,
#  'still': 12,
#  'practice': 1,
#  'yes': 1,
#  'right': 29,
#  'distance': 8,
#  'Latitude': 2,
#  'Longitude': 2,
#  'got': 45,
#  'idea': 15,
#  'nice': 6,
#  'grand': 3,
#  'words': 20,
#  'Presently': 2,
#  'began': 58,
#  'THROUGH': 1,
#  'funny': 3,
#  'seem': 8,
#  'among': 12,
#  'people': 13,
#  'walk': 5,
#  'their': 50,
#  'heads': 9,
#  'downward': 1,
#  'Antipathies': 1,
#  'rather': 25,
#  'glad': 11,
#  'WAS': 4,
#  'listening': 3,
#  'didn': 14,
#  'sound': 4,
#  'word': 10,
#  'ask': 10,
#  'them': 86,
#  'name': 10,
#  'country': 1,
#  'know': 77,
#  'Please': 5,
#  'Ma': 2,
#  'am': 16,
#  'New': 1,
#  'Zealand': 1,
#  'Australia': 1,
#  'curtsey': 1,
#  'spoke': 17,
#  'fancy': 7,
#  'CURTSEYING': 1,
#  're': 38,
#  'through': 13,
#  'air': 14,
#  'Do': 13,
#  'manage': 7,
#  'And': 67,
#  'ignorant': 1,
#  'little': 125,
#  'girl': 4,
#  'asking': 5,
#  'No': 20,
#  'perhaps': 14,
#  'written': 6,
#  'somewhere.': 1,
#  'else': 12,
#  'soon': 24,
#  'talking': 16,
#  'Dinah': 14,
#  'miss': 1,
#  'to-night': 1,
#  'should': 27,
#  'cat': 11,
#  'hope': 3,
#  'remember': 14,
#  'saucer': 1,
#  'milk': 1,
#  'tea-time': 2,
#  'my': 55,
#  'wish': 21,
#  'are': 44,
#  'mice': 4,
#  'm': 58,
#  'afraid': 12,
#  'might': 28,
#  'catch': 3,
#  'bat': 3,
#  'mouse': 13,
#  'But': 37,
#  'cats': 12,
#  'eat': 17,
#  'bats': 4,
#  'saying': 14,
#  'dreamy': 1,
#  'sometimes': 5,
#  'couldn': 9,
#  'answer': 9,
#  'question': 17,
#  'matter': 9,
#  'which': 41,
#  'felt': 23,
#  'dozing': 1,
#  'begun': 6,
#  'dream': 7,
#  'walking': 5,
#  'hand': 19,
#  'earnestly': 2,
#  'Now': 12,
#  'tell': 27,
#  'truth': 1,
#  'ever': 20,
#  'thump': 2,
#  'came': 40,
#  'heap': 1,
#  'sticks': 1,
#  'dry': 8,
#  'leaves': 6,
#  'bit': 15,
#  'hurt': 3,
#  'jumped': 6,
#  'overhead': 1,
#  'long': 31,
#  'passage': 4,
#  'sight': 10,
#  'hurrying': 1,
#  'lost': 3,
#  'away': 25,
#  'wind': 2,
#  'turned': 16,
#  'corner': 4,
#  'ears': 5,
#  'whiskers': 3,
#  'behind': 13,
#  'longer': 3,
#  'low': 14,
#  'hall': 9,
#  'lit': 1,
#  'row': 2,
#  'lamps': 1,
#  'hanging': 3,
#  'roof': 6,
#  'doors': 2,
#  'round': 41,
#  'locked': 1,
#  'been': 38,
#  'side': 17,
#  'other': 39,
#  'trying': 13,
#  'every': 12,
#  'door': 30,
#  'walked': 10,
#  'sadly': 5,
#  'middle': 7,
#  'wondering': 7,
#  'Suddenly': 1,
#  'three-legged': 2,
#  'table': 17,
#  'solid': 1,
#  'glass': 9,
#  'except': 4,
#  'tiny': 4,
#  'golden': 7,
#  'key': 9,
#  'first': 43,
#  'belong': 1,
#  'alas': 3,
#  'locks': 2,
#  'small': 10,
#  'any': 39,
#  'rate': 9,
#  'open': 7,
#  'However': 13,
#  'second': 4,
#  'curtain': 1,
#  'fifteen': 1,
#  'inches': 6,
#  'high': 15,
#  'lock': 1,
#  'delight': 3,
#  'fitted': 1,
#  'opened': 10,
#  'led': 4,
#  'larger': 7,
#  'than': 23,
#  'rat-hole': 1,
#  'knelt': 1,
#  'along': 6,
#  'loveliest': 1,
#  'garden': 15,
#  'longed': 2,
#  'wander': 1,
#  'those': 9,
#  'beds': 1,
#  'bright': 7,
#  'flowers': 2,
#  'cool': 2,
#  'fountains': 2,
#  'head': 50,
#  'doorway': 1,
#  'go': 47,
#  'poor': 25,
#  'shoulders': 4,
#  'shut': 5,
#  'telescope': 2,
#  'only': 47,
#  'knew': 15,
#  'begin.': 3,
#  'For': 13,
#  'out-of-the-way': 3,
#  'happened': 7,
#  'lately': 1,
#  'few': 9,
#  'indeed': 15,
#  'really': 11,
#  'impossible': 3,
#  'waiting': 8,
#  'back': 37,
#  'half': 21,
#  'hoping': 3,
#  'find': 21,
#  'rules': 3,
#  'shutting': 2,
#  'telescopes': 1,
#  'bottle': 10,
#  'certainly': 13,
#  'neck': 7,
#  'paper': 4,
#  'label': 2,
#  'DRINK': 2,
#  'ME': 6,
#  'beautifully': 2,
#  'printed': 1,
#  'letters': 1,
#  'It': 64,
#  'Drink': 1,
#  'wise': 2,
#  'THAT': 13,
#  'hurry': 11,
#  'marked': 6,
#  '“': 58,
#  'poison': 3,
#  '”': 55,
#  'read': 10,
#  'histories': 1,
#  'children': 10,
#  'who': 48,
#  'burnt': 1,
#  'eaten': 1,
#  'wild': 2,
#  'beasts': 2,
#  'unpleasant': 2,
#  'because': 14,
#  'WOULD': 5,
#  'simple': 5,
#  'friends': 2,
#  'taught': 4,
#  'red-hot': 1,
#  'poker': 1,
#  'will': 24,
#  'burn': 2,
#  'hold': 6,
#  'cut': 5,
#  'your': 53,
#  'finger': 5,
#  'deeply': 4,
#  'knife': 2,
#  'usually': 2,
#  'bleeds': 1,
#  'forgotten': 6,
#  'drink': 4,
#  'almost': 6,
#  'certain': 3,
#  'disagree': 1,
#  'sooner': 2,
#  'later': 3,
#  'NOT': 7,
#  'ventured': 4,
#  'taste': 2,
#  'finding': 3,
#  'fact': 7,
#  'mixed': 2,
#  'flavour': 1,
#  'cherry-tart': 1,
#  'custard': 1,
#  'pine-apple': 1,
#  'roast': 1,
#  'turkey': 1,
#  'toffee': 1,
#  'buttered': 1,
#  'toast': 1,
#  'finished': 11,
#  '*': 60,
#  'What': 42,
#  'curious': 18,
#  'feeling': 7,
#  'telescope.': 1,
#  'now': 44,
#  'ten': 5,
#  'face': 15,
#  'brightened': 2,
#  'size': 13,
#  'lovely': 2,
#  'however': 7,
#  'waited': 11,
#  'minutes': 11,
#  'shrink': 1,
#  'further': 3,
#  'nervous': 5,
#  'altogether': 5,
#  'candle': 3,
#  'flame': 1,
#  'blown': 1,
#  'thing': 49,
#  'After': 6,
#  'while': 20,
#  'more': 46,
#  'decided': 3,
#  'possibly': 3,
#  'reach': 4,
#  'plainly': 1,
#  'best': 10,
#  'climb': 1,
#  'legs': 3,
#  'slippery': 1,
#  'sat': 17,
#  'cried': 20,
#  'Come': 21,
#  'crying': 2,
#  'sharply': 4,
#  'advise': 1,
#  'leave': 7,
#  'minute': 21,
#  'generally': 7,
#  'gave': 13,
#  'advice': 1,
#  'seldom': 1,
#  'followed': 8,
#  'scolded': 1,
#  'severely': 4,
#  'bring': 2,
#  'tears': 10,
#  'remembered': 5,
#  'box': 4,
#  'cheated': 1,
#  'game': 11,
#  'croquet': 4,
#  'playing': 2,
#  'against': 9,
#  'child': 10,
#  'fond': 4,
#  'pretending': 1,
#  'two': 31,
#  'pretend': 1,
#  'hardly': 11,
#  'enough': 17,
#  'left': 14,
#  'ONE': 3,
#  'respectable': 1,
#  'person': 4,
#  'Soon': 1,
#  'eye': 7,
#  'lying': 8,
#  'cake': 3,
#  'EAT': 1,
#  'currants': 1,
#  'makes': 11,
#  'grow': 13,
#  'can': 58,
#  'smaller': 3,
#  'creep': 1,
#  'don': 51,
#  'care': 4,
#  'happens': 5,
#  'ate': 1,
#  'anxiously': 14,
#  'holding': 3,
#  'growing': 10,
#  'surprised': 7,
#  'remained': 3,
#  'same': 23,
#  'sure': 20,
#  'eats': 1,
#  'expecting': 3,
#  'dull': 3,
#  'life': 10,
#  'common': 1,
#  'set': 14,
#  'work': 8,
#  'II': 1,
#  'Pool': 1,
#  'Tears': 1,
#  'Curiouser': 1,
#  'curiouser': 1,
#  'forgot': 2,
#  'speak': 13,
#  'English': 6,
#  'opening': 3,
#  'largest': 1,
#  'Good-bye': 1,
#  'far': 13,
#  'shoes': 6,
#  'stockings': 1,
#  'dears': 3,
#  '_I_': 2,
#  'shan': 5,
#  'able': 1,
#  'deal': 12,
#  'myself': 5,
#  'kind': 7,
#  'won': 26,
#  'want': 9,
#  'give': 9,
#  'new': 4,
#  'pair': 5,
#  'boots': 2,
#  'Christmas.': 1,
#  'planning': 1,
#  'They': 21,
#  'carrier': 1,
#  'sending': 2,
#  'presents': 2,
#  'odd': 1,
#  'directions': 3,
#  'ALICE': 2,
#  'S': 6,
#  'RIGHT': 1,
#  'FOOT': 1,
#  'ESQ': 1,
#  'HEARTHRUG': 1,
#  'NEAR': 1,
#  'THE': 8,
#  'FENDER': 1,
#  'WITH': 1,
#  'LOVE': 1,
#  'nonsense': 5,
#  'Just': 7,
#  'struck': 2,
#  'nine': 5,
#  'Poor': 2,
#  'hopeless': 1,
#  'cry': 3,
#  'You': 51,
#  'ashamed': 2,
#  'yourself': 8,
#  'Stop': 1,
#  'shedding': 1,
#  'gallons': 1,
#  'until': 5,
#  'pool': 10,
#  'reaching': 1,
#  'heard': 30,
#  'pattering': 3,
#  'hastily': 16,
#  'dried': 1,
#  'returning': 1,
#  'splendidly': 1,
#  'dressed': 1,
#  'white': 8,
#  'kid': 5,
#  'gloves': 11,
#  'fan': 10,
#  'he': 101,
#  'trotting': 2,
#  'muttering': 3,
#  'himself': 6,
#  'Duchess': 42,
#  'savage': 4,
#  'kept': 13,
#  'desperate': 1,
#  'ready': 8,
#  'help': 9,
#  'timid': 3,
#  'voice': 47,
#  'If': 16,
#  'please': 13,
#  'sir': 6,
#  'violently': 4,
#  'dropped': 5,
#  'skurried': 1,
#  'darkness': 1,
#  'hard': 8,
#  'fanning': 1,
#  'Dear': 1,
#  'queer': 10,
#  'everything': 12,
#  'to-day': 2,
#  'yesterday': 3,
#  'usual': 5,
#  'changed': 8,
#  'night': 3,
#  'morning': 5,
#  'different': 9,
#  'Who': 15,
#  'Ah': 5,
#  'puzzle': 1,
#  'thinking': 10,
#  'age': 4,
#  'Ada': 1,
#  'hair': 6,
#  'goes': 7,
#  'ringlets': 2,
#  'mine': 6,
#  'doesn': 16,
#  'Mabel': 4,
#  'sorts': 3,
#  'oh': 10,
#  'knows': 2,
#  'Besides': 1,
#  'SHE': 5,
#  'puzzling': 4,
#  'try': 12,
#  'used': 13,
#  'times': 6,
#  'five': 1,
#  'twelve': 4,
#  'six': 2,
#  'thirteen': 1,
#  'seven': 1,
#  'twenty': 1,
#  'Multiplication': 1,
#  'Table': 1,
#  'signify': 1,
#  'let': 11,
#  'Geography': 1,
#  'London': 1,
#  'capital': 4,
#  'Paris': 2,
#  'Rome': 2,
#  'wrong': 5,
#  'doth': 2,
#  'crossed': 3,
#  'hands': 12,
#  'lap': 2,
#  'repeat': 6,
#  'sounded': 5,
#  'hoarse': 3,
#  'strange': 5,
#  'crocodile': 1,
#  'Improve': 1,
#  'his': 94,
#  'shining': 1,
#  'tail': 9,
#  'pour': 1,
#  'waters': 1,
#  'Nile': 1,
#  'On': 4,
#  'scale': 1,
#  'cheerfully': 1,
#  'seems': 5,
#  'grin': 5,
#  'neatly': 2,
#  'spread': 3,
#  'claws': 2,
#  'welcome': 1,
#  'fishes': 1,
#  'With': 4,
#  'gently': 3,
#  'smiling': 2,
#  'jaws': 2,
#  'live': 8,
#  'poky': 1,
#  'toys': 1,
#  'play': 8,
#  'learn': 7,
#  'stay': 5,
#  'putting': 3,
#  'Tell': 5,
#  'being': 19,
#  'till': 21,
#  'sudden': 5,
#  'burst': 1,
#  'alone': 4,
#  'As': 17,
#  'CAN': 4,
#  'done': 14,
#  'again.': 2,
#  'measure': 1,
#  'nearly': 10,
#  'guess': 3,
#  'shrinking': 4,
#  'rapidly': 2,
#  'cause': 3,
#  'avoid': 1,
#  'That': 27,
#  'narrow': 2,
#  'escape': 4,
#  'frightened': 7,
#  'change': 13,
#  'existence': 1,
#  'speed': 1,
#  'worse': 3,
#  'declare': 2,
#  'bad': 2,
#  'these': 11,
#  'foot': 9,
#  'slipped': 3,
#  'splash': 1,
#  'chin': 7,
#  'salt': 2,
#  'water': 4,
#  'Her': 3,
#  'somehow': 1,
#  'sea': 12,
#  'case': 5,
#  'railway': 2,
#  'seaside': 1,
#  'general': 3,
#  'conclusion': 2,
#  'wherever': 2,
#  'coast': 1,
#  'number': 4,
#  'bathing': 1,
#  'machines': 1,
#  'digging': 2,
#  'sand': 1,
#  'wooden': 1,
#  'spades': 1,
#  'lodging': 1,
#  'houses': 1,
#  'station': 1,
#  'wept': 1,
#  'hadn': 7,
#  'swam': 5,
#  'punished': 1,
#  'suppose': 11,
#  'drowned': 1,
#  'WILL': 3,
#  'to-day.': 1,
#  'something': 17,
#  'splashing': 2,
#  'nearer': 5,
#  'walrus': 1,
#  'hippopotamus': 1,
#  'Everything': 2,
#  'talk': 14,
#  'harm': 1,
#  'trying.': 1,
#  'O': 3,
#  'Mouse': 30,
#  'swimming': 2,
#  'speaking': 5,
#  'brother': 1,
#  'Latin': 1,
#  'Grammar': 1,
#  'inquisitively': 1,
#  'wink': 2,
#  'its': 56,
#  'Perhaps': 3,
#  'understand': 6,
#  'daresay': 1,
#  'French': 4,
#  'William': 6,
#  'Conqueror.': 1,
#  'history': 7,
#  'clear': 2,
#  'notion': 3,
#  'ago': 2,
#  'Ou': 1,
#  'est': 1,
#  'ma': 1,
#  'chatte': 1,
#  'sentence': 5,
#  'lesson-book': 1,
#  'leap': 1,
#  'quiver': 1,
#  'fright': 2,
#  'beg': 7,
#  'pardon': 6,
#  'animal': 2,
#  'feelings': 2,
#  'cats.': 1,
#  'Not': 9,
#  'shrill': 5,
#  'passionate': 1,
#  'YOU': 14,
#  'soothing': 1,
#  'tone': 40,
#  'angry': 5,
#  'yet': 19,
#  'show': 3,
#  'our': 7,
#  'd': 27,
#  'quiet': 2,
#  'lazily': 1,
#  'sits': 1,
#  'purring': 2,
#  'nicely': 2,
#  'fire': 3,
#  'licking': 1,
#  'paws': 4,
#  'washing': 2,
#  'soft': 1,
#  'nurse': 3,
#  'catching': 2,
#  'bristling': 1,
#  'offended': 10,
#  'We': 10,
#  'not.': 2,
#  'trembling': 6,
#  'subject': 6,
#  'Our': 1,
#  'family': 1,
#  'always': 12,
#  'HATED': 1,
#  'nasty': 1,
#  'vulgar': 1,
#  'Don': 9,
#  'conversation': 9,
#  'Are': 4,
#  'dogs': 2,
#  'eagerly': 8,
#  'dog': 3,
#  'bright-eyed': 1,
#  'terrier': 1,
#  'curly': 1,
#  'brown': 2,
#  'fetch': 6,
#  'throw': 3,
#  'sit': 6,
#  'dinner': 2,
#  ...}

# %%
l = [1, "432ida", ('oisd', 6.54)]
l.append("Alice")
l
# Out:
# [1, '432ida', ('oisd', 6.54), 'Alice']

# %%
d = {"Alice": 396,
 "dog": 4382,
 "cat": 413}

# %%
d["John"] = 653

# %% [markdown]
# # This is Lesson n. 2
# ## We are going talk more about scraping
#
# This i a paragraph. And this:
#   - is
#   - a
#   - list

# %% [markdown]
# <div data-testid="service-review-card-v2"><div class="styles_reviewCardInnerHeader__8Xqy8"><aside class="styles_consumerInfoWrapper__6HN5O" aria-label="Info for Carmine de Santo"><div class="styles_consumerDetailsWrapper__4eZod"><div class="CDS_Avatar_imageWrapper__dd7fc3" style="width:44px;height:44px;min-width:44px;min-height:44px" data-testid="consumer-avatar"><img alt="" data-consumer-avatar-image="true" loading="lazy" width="44" height="44" decoding="async" data-nimg="1" style="color:transparent" src="https://user-images.trustpilot.com/5f7ca520b0a0db0012236aac/73x73.png"></div><a data-cpl="true" href="/users/5f7ca520b0a0db0012236aac" rel="nofollow" name="consumer-profile" target="_self" class="link_internal__Eam_b link_wrapper__ahpyq styles_consumerDetails__POC79" data-consumer-profile-link="true"><span class="CDS_Typography_appearance-default__68c681 CDS_Typography_prettyStyle__68c681 CDS_Typography_heading-xs__68c681 styles_consumerName__xKr9c" data-consumer-name-typography="true">Carmine de Santo</span><div class="styles_consumerExtraDetails__NY6RP" data-consumer-reviews-count="18"><span class="CDS_Typography_appearance-subtle__68c681 CDS_Typography_prettyStyle__68c681 CDS_Typography_body-m__68c681" data-consumer-country-typography="true">IT</span><span class="CDS_Typography_appearance-subtle__68c681 CDS_Typography_prettyStyle__68c681 CDS_Typography_body-xs__68c681" data-lil-dot-typography="true">•</span><span class="CDS_Typography_appearance-subtle__68c681 CDS_Typography_prettyStyle__68c681 CDS_Typography_body-m__68c681" data-consumer-reviews-count-typography="true">18<!-- --> reviews</span></div></a></div></aside><div class="CDS_Typography_appearance-subtle__68c681 CDS_Typography_prettyStyle__68c681 CDS_Typography_body-m__68c681 styles_datesWrapper__jszhG"><time data-cpl="true" datetime="2026-01-29T20:04:09.000Z" class="" data-service-review-date-time-ago="true" title="Thursday, January 29, 2026 at 09:04:09 PM">Jan 29, 2026</time></div></div><section class="styles_reviewContentwrapper__K2aRu" aria-disabled="false"><div class="styles_reviewHeader__DzoAZ" data-service-review-rating="1"><img class="CDS_StarRating_starRating__614d2e" alt="Rated 1 out of 5 stars" width="108px" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-1.svg"></div><div class="styles_reviewContent__tuXiN" aria-hidden="false" lang="it" data-review-content="true"><a class="CDS_Typography_appearance-inherit__68c681 CDS_Typography_prettyStyle__68c681 CDS_Link_link__0e2efd CDS_Link_noUnderline__0e2efd" href="/reviews/697ba119a3391371df6e3488" rel="nofollow" data-review-title-typography="true"><h2 class="CDS_Typography_appearance-default__68c681 CDS_Typography_prettyStyle__68c681 CDS_Typography_heading-xs__68c681" data-service-review-title-typography="true">dispensa piena di pidocchi della pasta</h2></a><p class="CDS_Typography_appearance-default__68c681 CDS_Typography_prettyStyle__68c681 CDS_Typography_body-l__68c681" data-service-review-text-typography="true">Acquistato 5 kg di pasta Barilla, dopo 2 giorni avevo la dispensa piena di pidocchi della pasta, una confezione in particolare era piena, contatto assistenza Barilla con foto delle confezioni , lotto,  scadenza e scontrino, e dopo 2 settimane mi rispondono dicendo che gli dispiace.,.....  Per me potete anche fallire......<br></p><div class="styles_reviewBadges__Rmr_i"><div class="styles_badgesContainer__4pZPJ"><div class="CDS_Badge_badge__083901 CDS_Badge_s__083901 CDS_Badge_variant-subtle__083901 CDS_Badge_type-default__083901" data-testid="review-badge-date"><span class="CDS_Typography_appearance-inherit__68c681 CDS_Typography_prettyStyle__68c681 CDS_Typography_body-s__68c681 CDS_Typography_disableResponsiveSizing__68c681 CDS_Badge_badgeText__083901">December 18, 2025</span></div><div class="CDS_Badge_badge__083901 CDS_Badge_s__083901 CDS_Badge_variant-subtle__083901 CDS_Badge_type-default__083901" data-testid="review-badge-unprompted"><span class="CDS_Typography_appearance-inherit__68c681 CDS_Typography_prettyStyle__68c681 CDS_Typography_body-s__68c681 CDS_Typography_disableResponsiveSizing__68c681 CDS_Badge_badgeText__083901">Unprompted review</span></div></div></div></div></section><div class="styles_wrapper___luvQ styles_actionsWrapper__PJqVW"><div class="styles_buttonWrapper__CccMW"><button class="CDS_Typography_appearance-subtle__68c681 CDS_Typography_prettyStyle__68c681 CDS_Link_link__0e2efd buttons_actionButtons__SZCAW buttons_button__ECb04 CDS_Link_asButton__0e2efd CDS_Link_buttonInherit__0e2efd CDS_Link_noUnderline__0e2efd" name="find-useful" data-find-useful-button="true"><svg aria-hidden="true" viewBox="0 0 16 16" fill="inherit" class="CDS_Icon_icon__96d650 CDS_Icon_inherit__96d650" xmlns="http://www.w3.org/2000/svg" width="14px" height="14px" role="img"><path fill-rule="evenodd" clip-rule="evenodd" d="M7.94.94A1.5 1.5 0 0 1 10.5 2a20.774 20.774 0 0 1-.384 4H14.5A1.5 1.5 0 0 1 16 7.5v.066l-1.845 6.9-.094.095A1.5 1.5 0 0 1 13 15H9c-.32 0-.685-.078-1.038-.174-.357-.097-.743-.226-1.112-.349l-.008-.003c-.378-.126-.74-.246-1.067-.335C5.44 14.047 5.18 14 5 14v.941l-5 .625V6h5v.788c.913-.4 1.524-1.357 1.926-2.418A10.169 10.169 0 0 0 7.5 1.973 1.5 1.5 0 0 1 7.94.939ZM8 2l.498.045v.006l-.002.013a4.507 4.507 0 0 1-.026.217 11.166 11.166 0 0 1-.609 2.443C7.396 5.951 6.541 7.404 5 7.851V13c.32 0 .685.078 1.038.174.357.097.743.226 1.112.349l.008.003c.378.126.74.246 1.067.335.335.092.594.139.775.139h4a.5.5 0 0 0 .265-.076l1.732-6.479A.5.5 0 0 0 14.5 7H8.874l.138-.61c.326-1.44.49-2.913.488-4.39a.5.5 0 0 0-1 0v.023l-.002.022L8 2ZM4 7H1v7.434l3-.375V7Zm-1.5 5.75a.25.25 0 1 0 0-.5.25.25 0 0 0 0 .5Zm-.75-.25a.75.75 0 1 1 1.5 0 .75.75 0 0 1-1.5 0Z"></path></svg><span class="CDS_Typography_appearance-inherit__68c681 CDS_Typography_prettyStyle__68c681 CDS_Typography_body-m__68c681 styles_usefulLabel__VcnL3">Useful</span></button></div><button class="CDS_Typography_appearance-subtle__68c681 CDS_Typography_prettyStyle__68c681 CDS_Link_link__0e2efd buttons_actionButtons__SZCAW buttons_button__ECb04 CDS_Link_asButton__0e2efd CDS_Link_buttonInherit__0e2efd CDS_Link_noUnderline__0e2efd" aria-label="Share" name="share-review" data-share-review-button="true" type="button" aria-haspopup="dialog" aria-expanded="false" aria-controls="radix-:r13:" data-state="closed"><svg aria-hidden="true" viewBox="0 0 16 16" fill="inherit" class="CDS_Icon_icon__96d650" xmlns="http://www.w3.org/2000/svg" width="14px" height="14px" role="img" style="fill: currentcolor;"><path fill-rule="evenodd" clip-rule="evenodd" d="M13 1a2 2 0 1 0 0 4 2 2 0 0 0 0-4Zm-3 2a3 3 0 1 1 .583 1.778L5.867 7.115a3 3 0 0 1 0 1.77l4.716 2.337a3 3 0 1 1-.45.893L5.417 9.778a3 3 0 1 1 0-3.556l4.716-2.337A3.002 3.002 0 0 1 10 3ZM1 8a2 2 0 1 1 4 0 2 2 0 0 1-4 0Zm10 5a2 2 0 1 1 4 0 2 2 0 0 1-4 0Z"></path></svg><span class="CDS_Typography_appearance-inherit__68c681 CDS_Typography_prettyStyle__68c681 CDS_Typography_body-m__68c681">Share</span></button><button class="styles_iconButton__Sr5FD" aria-label="Flag this review" title="Flag this review" data-report-review-button="true"><svg aria-hidden="true" viewBox="0 0 16 16" fill="inherit" class="CDS_Icon_icon__96d650 CDS_Icon_default__96d650" xmlns="http://www.w3.org/2000/svg" width="16px" height="16px" role="img" data-report-icon="true"><path fill-rule="evenodd" clip-rule="evenodd" d="M3 .25V0H2v16h1V9.25h11.957l-4.5-4.5 4.5-4.5H3Zm0 1v7h9.543l-3.5-3.5 3.5-3.5H3Z"></path></svg></button></div></div>

# %%
import requests
from bs4 import BeautifulSoup
r = requests.get('https://www.trustpilot.com/review/barilla.it')
source = r.text
soup = BeautifulSoup(source)

# %%
res = soup.find_all('section', class_='styles_reviewContentwrapper__K2aRu')

# %%
tag = res[0]
tag.find_all('p', class_ = "CDS_Typography_appearance-default__68c681 CDS_Typography_prettyStyle__68c681 CDS_Typography_body-l__68c681")
# Out:
# [<p class="CDS_Typography_appearance-default__68c681 CDS_Typography_prettyStyle__68c681 CDS_Typography_body-l__68c681" data-service-review-text-typography="true">Acquistato 5 kg di pasta Barilla, dopo 2 giorni avevo la dispensa piena di pidocchi della pasta, una confezione in particolare era piena, contatto assistenza Barilla con foto delle confezioni , lotto,  scadenza e scontrino, e dopo 2 settimane mi rispondono dicendo che gli dispiace.,.....  Per me potete anche fallire......<br/></p>]

# %%
def get_tag_info(t):
    out = {}
    main_text = t.find('p', class_ = "CDS_Typography_appearance-default__68c681 CDS_Typography_prettyStyle__68c681 CDS_Typography_body-l__68c681")
    out['text'] = main_text.get_text()
    pol = t.find('img', class_='CDS_StarRating_starRating__614d2e').attrs['src'][-5]
    out['sentiment'] = pol
    return out

get_tag_info(res[2])
# Out:
# {'text': 'Comprati diversi pacchi di pasta in offerta, buona di sapore e resistente alla cottura',
#  'sentiment': '5'}

# %%
for t in res:
    print(get_tag_info(t))
# Out:
# {'text': 'Acquistato 5 kg di pasta Barilla, dopo 2 giorni avevo la dispensa piena di pidocchi della pasta, una confezione in particolare era piena, contatto assistenza Barilla con foto delle confezioni , lotto,  scadenza e scontrino, e dopo 2 settimane mi rispondono dicendo che gli dispiace.,.....  Per me potete anche fallire......', 'sentiment': '1'}
# {'text': 'Ho comprato e cucinato secondo le indicazioni riportate sulla confezione le lasagne Barilla. Il risultato è stato deludente. Lasagne rotte in mille piccoli pezzi e per di più crude. Il prodotto è assolutamente scadente. Mai più le comprerò.', 'sentiment': '1'}
# {'text': 'Comprati diversi pacchi di pasta in offerta, buona di sapore e resistente alla cottura', 'sentiment': '5'}
# {'text': 'Ho comprato una scatola di fusilli integrali ma dentro alla scatola ho trovato anche delle penne non integrali ', 'sentiment': '1'}
# {'text': 'Nelle Farfalline escono insetti comprata ieri', 'sentiment': '1'}
# {'text': 'pasta tutto sommato buona, con il pesto top', 'sentiment': '3'}
# {'text': 'Ho acquistato dei pacchi di pasta in offerta con scadenza 2027 e il giorno dopo ne ho aperto uno di penne e al momento di scolarla ho visto a galla dei vermi, ho controllato la scatola e ho notato sulla base interna del cartone alcuni puntini neri e dei vermi vivi e sulla pasta delle uova bianchicce. Risultato, buttato via la pasta e a letto senza cena per lo schifo. Scandaloso', 'sentiment': '1'}
# {'text': 'Die Werbung ist Müll. Also kommt die Sosse ind den Abwasch, wenn keine Nudeln mehr da sind. Mit Brot essen verboten. Sehe mehrere Teller mit Soße aber keine Spaghetti mehr. Was für eine dumme Werbung', 'sentiment': '1'}
# {'text': "Buona sera,ha un periodo di giorni che nella pasta Barilla  specialmente  negli spaghetti  trovo,u sia durante la cottura,che anche aprendo la confezione,dei punti neri che si trasformano in piccolissimi insetti duri di colore nero.Ho fatto presente al responsabile del supermercato che prontamente me l'ha sostituito,ma anche altra confezione aveva lo stesso problema.Ora  si inuisce che anche se le confezioni sono integre e non scadute, questo mi porta a cercare altra marca di pasta e questa anomalia c:e anche in alcuni della De Cecco.Tanto si segnale per il seguito di competenza ", 'sentiment': '5'}
# {'text': "La qualità dei prodotti!Gli impegni di Barilla nel mondo! E per ultimo:L' ultima pubblicità con le corse è P A Z Z E S CA! 💓 congratulazioni!!!", 'sentiment': '5'}
# {'text': ' Pessima,non comprerò mai più pasta Barilla, ho speso quasi 80€ di pasta e messa in dispensa, dopo 2 giorni mia moglie la presa per cucinare e c’erano in tutti i parchi  con vermi piccoli, ho dovuto buttare tutto !!!', 'sentiment': '1'}
# {'text': "Sono cliente da una vita, compro spesso prodotti del mulino bianco, precisamente i biscotti *Ritornelli*L'ultima volta  all'interno li ho trovati frantumati, polverosi, spezzettati, uno schifo se si può descrivere. Com'è possibile? Non comprerò più questi prodotti ", 'sentiment': '1'}
# {'text': 'Non acquistate pasta Barilla perché contaminata da punteruolo del grano.Ho dovuto buttare tutto dalla dispensa.Sconsigliatissima.', 'sentiment': '1'}
# {'text': 'Un’azienda storica non puo permettersi di consegnare ai consumatori la pasta “gia condita“ cioe con pidocchi neri che ho intravisto rovesciando la confezione nello pentola in ebollizione. VERGOGNA!!!!!', 'sentiment': '1'}
# {'text': "Erano alcuni giorni che vedevo volare per casa delle piccole mosche. Oggi ne ho viste volare almeno 6 nella cucina. A  quel punto ho controllato i prodotti che avevo nella dispensa e con mia sorpresa ho trovato in più pacchi della Barilla anche acquistati soltanto il giorno precedente alcuni vermi ancora in procinto di diventare mosche. Inutile che mi dilunghi sull'argomento visto che anche altri clienti hanno avuto la stessa esperienza.", 'sentiment': '1'}
# {'text': 'All 3* pacco di pasta buttato appena aperto, ho deciso di fare una recensione. Ma con poca sorpresa ho trovato che il70% delle recensioni sono negative con il mio stesso problema. I pacchi con scadenza 2027, presentavano “muffe bianche” ed erano pieni di pidocchi della pasta. Evidentemente le svendite della Barilla più volte incontrate nell’ultimo anno servono proprio a recuperare in po’ di denaro da derrate altrimenti da gettare.', 'sentiment': '1'}
# {'text': "Ho acquistato 6 pacchi di pasta in offerta con scadenza 2026, ne ho aperto uno il giorno stesso per  cucinarla e con mia grande sorpresa ho notato sulla base interna del cartone alcuni puntini neri. Successivamente, sono venuti a galla farfalline e vermi nell'acqua di cottura della pentola, esaminando anche gli altri pacchetti acquistati ho trovato la stessa situazione, tranne nel pacco di spaghetti integrali, gli unici di diverso tipo comprato. Che dire... Scandaloso. ", 'sentiment': '1'}
# {'text': 'ottima pasta da sempre il riferimento per gli italiani nel mondo. sarebbe meglio però selezionare meglio i grani non ue', 'sentiment': '4'}
# {'text': 'In seguito alla presenza di un corpo estraneo in un prodotto (in Francia), il servizio clienti mi ha chiesto di inviare loro tutte le prove. Quando chiedo come verrò risarcito per la mia perdita di tempo, la risposta è "in buoni".Un totale disprezzo per il cliente, che viene trattato come un servo della gleba dai signori dalla sicurezza del loro castello.', 'sentiment': '1'}
# {'text': 'Acquistato un pacco da 1 kg di Mezze Penne Rigate. Scatola appena aperta mezza vuota. La peso: 710 gr compresi di scatola! Ho fatto la segnalazione al servizio clienti e non ho nemmeno mai avuto una risposta! La serietà! ', 'sentiment': '1'}

# %% [markdown]
# <img class="CDS_StarRating_starRating__614d2e" alt="Rated 1 out of 5 stars" width="108px" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-1.svg">

# %%
l = [43, 65, 67, 12]

# %%
s = "sdjhdajahdba"
s[1:5]
# Out:
# 'djhd'

# %% [markdown]
# ### 💡 Pro-Tip: Dictionaries
# Instead of just using a variable, we often use **Dictionaries** to store pairs of related data (like words and their frequencies, or students and their scores).

# %%
# Demonstrating a basic dictionary operation
student_scores = {'Alice': 95, 'Bob': 88}
print(student_scores)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 gino
#
# NameError: name 'gino' is not defined
